# %%
"hello world!"
# Out:
# 'hello world!'

# %%
#list
brand_list = ["Apple", "Google", "Microsoft"]
storage_list = [32, 64, 128]
price_list = [1000, 2000, 3000]

print(brand_list)
print(len(brand_list))
print(storage_list)
print(len(storage_list))
print(price_list)
print(len(price_list))
# Out:
# ['Apple', 'Google', 'Microsoft']
# 3
# [32, 64, 128]
# 3
# [1000, 2000, 3000]
# 3

# %%
#minimum price
print(min(price_list))
#maximum price
print(max(price_list))
#sum of price
print(sum(price_list))
print(price_list)
# Out:
# 1000
# 3000
# 6000
# [1000, 2000, 3000]

# %%
print(storage_list[0])
# Out:
# 32

# %%
print(storage_list[0:2])
print(storage_list)
# Out:
# [32, 64]
# [32, 64, 128]

# %%
print(storage_list[1:])
print(storage_list)
# Out:
# [64, 128]
# [32, 64, 128]

# %%
print(storage_list[:2])
print(storage_list)
# Out:
# [32, 64]
# [32, 64, 128]

# %%
print(storage_list[-1])
print(storage_list)
# Out:
# 128
# [32, 64, 128]

# %%
print(storage_list[:-1])    
print(storage_list)
# Out:
# [32, 64]
# [32, 64, 128]

# %%
print(storage_list[-2:])
print(storage_list)
# Out:
# [64, 128]
# [32, 64, 128]

# %%
# It means:
# start → beginning of the list
# stop → end of the list
# step → 2 (take every second element)
print(storage_list[::2])  # list[start : stop : step]
print(storage_list)
# Out:
# [32, 128]
# [32, 64, 128]

# %%
storage_list.append(256)
print(storage_list)
# Out:
# [32, 64, 128, 256]

# %%
storage_list.remove(256)
print(storage_list)
# Out:
# [32, 64, 128]

# %%
storage_list.insert(1, 256)
print(storage_list)
# Out:
# [32, 256, 64, 128]

# %%
storage_list.pop(1)
print(storage_list)
# Out:
# [32, 64, 128]

# %%
alphabets = {'1':'A','2':'B','3': ['C','D','E']}
alphabets['3'][2]
# Out:
# 'E'

# %%
color = ['white','red', 'blue', 'green','blue','yellow', 'black']
#//remove yellow color
#color.remove('yellow')
color.pop(5)
print(color)
# Out:
# ['white', 'red', 'blue', 'green', 'blue', 'black']

# %%
a = -99
if a > 0:
 print("Number is Positive")
else:
 print("Number is negative")
# Out:
# Number is negative

# %%
a = "I am a Data Scientist"
if "Data" in a:
 print("It is present")
else:
 print(False)
# Out:
# It is present
