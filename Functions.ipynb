# %%
# write a functions that displays attribute of Applie Iphone

def display_details(name, color, price):
    '''Explains what the function does'''
    print(f"Name: {name}")
    print(f"Color: {color}")
    print(f"Price: {price}")

# call the function 
display_details("Iphone 13", "Space Gray", "$999")
# Out:
# Name: Iphone 13
# Color: Space Gray
# Price: $999

# %%
#lanmbda function
display_details = lambda name, color, price: print(f"Name: {name}\nColor: {color}\nPrice: {price}")
display_details("Iphone 13", "Space Gray", "$999")
# Out:
# Name: Iphone 13
# Color: Space Gray
# Price: $999

# %%
def say(message, times):
    print(message*times)
say("How are you", 2)
# Out:
# How are youHow are you

# %%
def func(a):
  print(a)
A = [0,1,2,3]
func(A)
# Out:
# [0, 1, 2, 3]

# %%
mul = lambda a,b: print(a*b)
mul(5,6)
# Out:
# 30

# %%
(lambda x: (x+2)*5//2)(4)
# Out:
# 15

# %%
(lambda x: (x+2)*5/2)(4)
# Out:
# 15.0

# %%
def outer(x):
    def inner(y):
        return x + y
    return inner

add5 = outer(5)
print(add5(3))
# Out:
# 8

# %%
def sum(a,b):
    return a+b

print(sum(5,4))
# Out:
# 9

# %%
5 == (3 + 2)
# Out:
# True

# %%
a = 3
print(a + (33))
# Out:
# 36

# %%
a = '5a'
#int(a) #error

# %%
repeated_list = [2] * 4
print(repeated_list)
# Out:
# [2, 2, 2, 2]
