# %%
a = int(input())
b = int(input())
c = int(input())

if a > 0:
    if b % 2 == 0:
        if c % 3 == 0:
            print("All conditions are satisfied")
        else:
            print("Conditions are not satisfied")
    else:
        print("Conditions are not satisfied")
else:
    print("Conditions are not satisfied")
